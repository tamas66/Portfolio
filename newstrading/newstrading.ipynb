# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

# Corrected file path
df = pd.read_csv('NewsData.io_Sample_data.csv')
df
# Out:
#                           article_id  \
# 0   efb99cb30b4bdc19eadbd7737dcb8977
# 1   536e9779d37385f3469be849418e638d
# 2   fe3316ed9a64efd0ec537c9c459f51c0
# 3   f08b9637cd5b4f3b501eb65f4ae75abb
# 4   3d86e412dc4a2d19cebb696eb4476497
# ..                               ...
# 85  ed2d463c7282c327a7c86249f650df81
# 86  29d9eb3e17a58ee481e137191298e8d8
# 87  d943542b45b198a92ca3e5b79e121c09
# 88  8975d1f8a3f2ef832ab12b4e09bd6748
# 89  9274c7d0b801244d57b27660b982eb72
#
#                                                 title  \
# 0        4 Bedroom Home in CHARLOTTESVILLE - $575,000
# 1                3 Bedroom Home in Lincoln - $689,000
# 2      4 Bedroom Home in CHARLOTTESVILLE - $2,875,000
# 3   AMIRI SS25 Combines 19th Century Western Trope...
# 4   Frederique Constant Readies a Duo of Highlife ...
# ..                                                ...
# 85  At Olympic trials, deaf runner Eric Gregory wi...
# 86  Watch: MSNBC host spars with guest in heated d...
# ...
