# %%
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from urllib.request import urlopen
from urllib.request import Request
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df = pd.read_csv('NewsData.io_Sample_data_crypto.csv')

# %%
df.isna().sum()
# Out:
# article_id           0
# title                0
# link                 0
# keywords            24
# creator             24
# video_url          100
# description          7
# content              0
# pubDate              0
# image_url            0
# source_id            0
# source_priority      0
# source_url           0
# source_icon          1
# language             0
# ai_tag               0
# sentiment            0
# sentiment_stats      0
# dtype: int64

# %%
df['content'].dropna(inplace=True)
df.drop_duplicates(inplace=True)
df = df[df['language'] == 'english']
df = df[['title','description', 'content', 'source_id', 'ai_tag', 'link', 'pubDate']]
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                                 title  \
# 0   Billionaire Winklevoss Twins Donate $2 Million...
# 1   AI and blockchain solutions for unclaimed asse...
# 2   Winklevoss twins donate $2 million in bitcoin ...
# 3   As Trump Promises Donors Big Policy Favors, Ca...
# 4   "600 Digital Assets on Korean Exchanges Face Q...
# ..                                                ...
# 95               Crypto's Long-Tail Disruptive Trends
# 96  Jump Crypto Adds $10M to Industry's U.S. Polit...
# 97  Mode Integrates the Industry-Standard Chainlin...
# 98  Kraken Says Hackers Turned to 'Extortion' Afte...
# 99  Crypto probe: ED arrests alleged member of int...
#
#                                           description  \
# 0   Tyler Winklevoss said they will be voting for ...
# 1   The latest data indicates that unclaimed depos...
# 2   Tyler and Cameron Winklevoss, the billionaire ...
# 3   Trump is raking in cash from billionaires, fos...
# 4   South Korea's financial authorities are set to...
# ..                                                ...
# 95  Interoperability between blockchain networks. ...
# 96  Jump Crypto put another $10 million into the U...
# 97  CCIP is secured by battle-tested Chainlink inf...
# 98  The bug found by a "security researcher" led t...
# 99  The investigation concerns a Delhi-based compa...
#
#                                               content     source_id  \
# 0   Share to Facebook Share to Twitter Share to Li...        forbes
# 1   Blockchain can provide a transparent mechanism...      livemint
# 2   The billionaire Winklevoss twins, founders of ...           toi
# 3   As Donald Trump seeks a second presidential te...  rollingstone
# 4   South Korea's financial authorities are set to...     it_chosun
# ..                                                ...           ...
# 95  The first half of 2024 has started a new cycle...      coindesk
# 96  Jump Crypto put another $10 million into the U...      coindesk
# 97  , /PRNewswire/ -- , the L2 that rewards users ...        cision
# 98  Crypto exchange Kraken said "security research...      coindesk
# 99  The Enforcement Directorate (ED) has arrested ...      thehindu
#
#                      ai_tag  \
# 0      founders & investors
# 1     blockchain,technology
# 2      founders & investors
# 3                government
# 4       government,adoption
# ..                      ...
# 95    blockchain,technology
# 96       government,economy
# 97    technology,blockchain
# 98  scam,security & privacy
# 99  scam,security & privacy
#
#                                                  link              pubDate
# 0   https://www.forbes.com/sites/siladityaray/2024...  2024-06-21 04:50:52
# 1   https://www.livemint.com/money/personal-financ...  2024-06-21 04:47:43
# 2   https://timesofindia.indiatimes.com/business/c...  2024-06-21 02:49:44
# 3   https://www.rollingstone.com/politics/politics...  2024-06-21 02:48:27
# 4   https://it.chosun.com/news/articleView.html?id...  2024-06-21 02:45:40
# ..                                                ...                  ...
# 95  https://www.coindesk.com/opinion/2024/06/19/cr...  2024-06-19 16:16:39
# 96  https://www.coindesk.com/policy/2024/06/19/jum...  2024-06-19 16:00:00
# 97  https://www.prnewswire.com/news-releases/mode-...  2024-06-19 16:00:00
# 98  https://www.coindesk.com/business/2024/06/19/k...  2024-06-19 15:22:14
# 99  https://www.thehindu.com/news/national/crypto-...  2024-06-19 14:56:35
#
# [100 rows x 7 columns]

# %%
df
# Out:
#                           article_id  \
# 0   171aa19fec6e2bed717941a11e09de2b
# 1   221c78f74e33b32fbe79a7db198aec5f
# 2   2c69e415635871633b8f28fa9d1cf734
# 3   9a74608442e0790d6958445ea78eb27c
# 4   9e5e5b5e7f5614936f32a4a35a672791
# ..                               ...
# 95  b0b202ca7a5ebf001b339ef32a94f316
# 96  ddf1a37b4eb725cbc9e502cd026a6943
# 97  911db46c56da321fcea07203b1655b2e
# 98  7fb857c670eb4951cce7670dbf3f9407
# 99  c0e0cd51209be75b7e52c3205c660eb0
#
#                                                 title  \
# 0   Billionaire Winklevoss Twins Donate $2 Million...
# 1   AI and blockchain solutions for unclaimed asse...
# 2   Winklevoss twins donate $2 million in bitcoin ...
# 3   As Trump Promises Donors Big Policy Favors, Ca...
# 4   "600 Digital Assets on Korean Exchanges Face Q...
# ..                                                ...
# 95               Crypto's Long-Tail Disruptive Trends
# 96  Jump Crypto Adds $10M to Industry's U.S. Polit...
# 97  Mode Integrates the Industry-Standard Chainlin...
# 98  Kraken Says Hackers Turned to 'Extortion' Afte...
# 99  Crypto probe: ED arrests alleged member of int...
#
#                                                  link  \
# 0   https://www.forbes.com/sites/siladityaray/2024...
# 1   https://www.livemint.com/money/personal-financ...
# 2   https://timesofindia.indiatimes.com/business/c...
# 3   https://www.rollingstone.com/politics/politics...
# 4   https://it.chosun.com/news/articleView.html?id...
# ..                                                ...
# 95  https://www.coindesk.com/opinion/2024/06/19/cr...
# 96  https://www.coindesk.com/policy/2024/06/19/jum...
# 97  https://www.prnewswire.com/news-releases/mode-...
# 98  https://www.coindesk.com/business/2024/06/19/k...
# 99  https://www.thehindu.com/news/national/crypto-...
#
#                                              keywords  \
# 0   election 2024,breaking-news,election-2024,brea...
# 1                                                 NaN
# 2                                                 NaN
# 3   campaign fundraising,politics news,politics,fo...
# 4                                                 NaN
# ..                                                ...
# 95  opinion,opinion,opinion,crypto long & short,ad...
# 96  policy,news,regulations,stand with crypto,camp...
# 97  net,networks,bln,computer & electronics,stw,co...
# 98     finance,news,kraken,hacker,white-hat,exchanges
# 99                                              india
#
#                                 creator  video_url  \
# 0          ,Siladitya Ray, Forbes Staff        NaN
# 1                                   NaN        NaN
# 2                     TOI Business Desk        NaN
# 3                          Andrew Perez        NaN
# 4   wonjaeyeon@chosunbiz.com (Jess Won)        NaN
# ..                                  ...        ...
# 95                     Santiago Velasco        NaN
# 96                       Jesse Hamilton        NaN
# 97                                  NaN        NaN
# 98                         Aoyon Ashraf        NaN
# 99                                  NaN        NaN
#
#                                           description  \
# 0   Tyler Winklevoss said they will be voting for ...
# 1   The latest data indicates that unclaimed depos...
# 2   Tyler and Cameron Winklevoss, the billionaire ...
# 3   Trump is raking in cash from billionaires, fos...
# 4   South Korea's financial authorities are set to...
# ..                                                ...
# 95  Interoperability between blockchain networks. ...
# 96  Jump Crypto put another $10 million into the U...
# 97  CCIP is secured by battle-tested Chainlink inf...
# 98  The bug found by a "security researcher" led t...
# 99  The investigation concerns a Delhi-based compa...
#
#                                               content              pubDate  \
# 0   Share to Facebook Share to Twitter Share to Li...  2024-06-21 04:50:52
# 1   Blockchain can provide a transparent mechanism...  2024-06-21 04:47:43
# 2   The billionaire Winklevoss twins, founders of ...  2024-06-21 02:49:44
# 3   As Donald Trump seeks a second presidential te...  2024-06-21 02:48:27
# 4   South Korea's financial authorities are set to...  2024-06-21 02:45:40
# ..                                                ...                  ...
# 95  The first half of 2024 has started a new cycle...  2024-06-19 16:16:39
# 96  Jump Crypto put another $10 million into the U...  2024-06-19 16:00:00
# 97  , /PRNewswire/ -- , the L2 that rewards users ...  2024-06-19 16:00:00
# 98  Crypto exchange Kraken said "security research...  2024-06-19 15:22:14
# 99  The Enforcement Directorate (ED) has arrested ...  2024-06-19 14:56:35
#
#                                             image_url     source_id  \
# 0   https://imageio.forbes.com/specials-images/ima...        forbes
# 1   https://www.livemint.com/lm-img/img/2024/06/20...      livemint
# 2   https://static.toiimg.com/photo/msid-111153747...           toi
# 3   https://www.rollingstone.com/wp-content/upload...  rollingstone
# 4   https://cdn.it.chosun.com/news/photo/202406/20...     it_chosun
# ..                                                ...           ...
# 95  https://www.coindesk.com/resizer/7e1aYexq8TAbQ...      coindesk
# 96  https://www.coindesk.com/resizer/BZdDDEeQkA3GH...      coindesk
# 97  https://mma.prnewswire.com/media/2442211/Mode_...        cision
# 98  https://www.coindesk.com/resizer/LpdJZUtVfbxxm...      coindesk
# 99  https://th-i.thgim.com/public/incoming/ip10jo/...      thehindu
#
#     source_priority                           source_url  \
# 0                57               https://www.forbes.com
# 1              7134             https://www.livemint.com
# 2               391  https://timesofindia.indiatimes.com
# 3               289         https://www.rollingstone.com
# 4              7688                https://it.chosun.com
# ..              ...                                  ...
# 95              633             https://www.coindesk.com
# 96              633             https://www.coindesk.com
# 97             1625           https://www.prnewswire.com
# 98              633             https://www.coindesk.com
# 99             2972             https://www.thehindu.com
#
#                                           source_icon language  \
# 0         https://i.bytvi.com/domain_icons/forbes.png  english
# 1       https://i.bytvi.com/domain_icons/livemint.png  english
# 2            https://i.bytvi.com/domain_icons/toi.png  english
# 3   https://i.bytvi.com/domain_icons/rollingstone.png  english
# 4                                                 NaN  english
# ..                                                ...      ...
# 95  https://i.bytvi.com/domain_icons_crypto/coinde...  english
# 96  https://i.bytvi.com/domain_icons_crypto/coinde...  english
# 97        https://i.bytvi.com/domain_icons/cision.jpg  english
# 98  https://i.bytvi.com/domain_icons_crypto/coinde...  english
# 99      https://i.bytvi.com/domain_icons/thehindu.png  english
#
#                      ai_tag sentiment  \
# 0      founders & investors  positive
# 1     blockchain,technology   neutral
# 2      founders & investors  positive
# 3                government   neutral
# 4       government,adoption   neutral
# ..                      ...       ...
# 95    blockchain,technology   neutral
# 96       government,economy  positive
# 97    technology,blockchain   neutral
# 98  scam,security & privacy  negative
# 99  scam,security & privacy  negative
#
#                                 sentiment_stats
# 0    positive:79.58,neutral:13.45,negative:6.97
# 1      positive:4.56,neutral:94.04,negative:1.4
# 2    positive:88.67,neutral:10.36,negative:0.97
# 3   positive:28.86,neutral:36.26,negative:34.88
# 4     positive:0.58,neutral:98.73,negative:0.69
# ..                                          ...
# 95   positive:12.81,neutral:85.28,negative:1.91
# 96    positive:89.07,neutral:9.19,negative:1.74
# 97   positive:42.89,neutral:56.97,negative:0.14
# 98   positive:0.24,neutral:10.14,negative:89.62
# 99    positive:0.22,neutral:45.0,negative:54.79
#
# [100 rows x 18 columns]
